# %%
import warnings
warnings.filterwarnings('ignore')
import pickle
import numpy as np
import pandas as pd
import json
from textblob import TextBlob
import nltk
from scipy import spatial
import torch
import spacy
en_nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# (I tried to store the below code chunk in a separate file and import it but was running into some issues -> it essentially contains the code necessary to run the InferSent model)

# %%
# Copyright (c) 2017-present, Facebook, Inc.
# All rights reserved.
#
# This source code is licensed under the license found in the
# LICENSE file in the root directory of this source tree.
#

"""
This file contains the definition of encoders used in https://arxiv.org/pdf/1705.02364.pdf
"""

import numpy as np
import time

import torch
import torch.nn as nn


class InferSent(nn.Module):

    def __init__(self, config):
        super(InferSent, self).__init__()
        self.bsize = config['bsize']
        self.word_emb_dim = config['word_emb_dim']
        self.enc_lstm_dim = config['enc_lstm_dim']
        self.pool_type = config['pool_type']
        self.dpout_model = config['dpout_model']
        self.version = 1 if 'version' not in config else config['version']

        self.enc_lstm = nn.LSTM(self.word_emb_dim, self.enc_lstm_dim, 1,
                                bidirectional=True, dropout=self.dpout_model)

        assert self.version in [1, 2]
        if self.version == 1:
            self.bos = '<s>'
            self.eos = '</s>'
            self.max_pad = True
            self.moses_tok = False
        elif self.version == 2:
            self.bos = '<p>'
            self.eos = '</p>'
            self.max_pad = False
            self.moses_tok = True

    def is_cuda(self):
        # either all weights are on cpu or they are on gpu
        return self.enc_lstm.bias_hh_l0.data.is_cuda

    def forward(self, sent_tuple):
        # sent_len: [max_len, ..., min_len] (bsize)
        # sent: (seqlen x bsize x worddim)
        sent, sent_len = sent_tuple

        # Sort by length (keep idx)
        sent_len_sorted, idx_sort = np.sort(sent_len)[::-1], np.argsort(-sent_len)
        sent_len_sorted = sent_len_sorted.copy()
        idx_unsort = np.argsort(idx_sort)

        idx_sort = torch.from_numpy(idx_sort).cuda() if self.is_cuda() \
            else torch.from_numpy(idx_sort)
        sent = sent.index_select(1, idx_sort)

        # Handling padding in Recurrent Networks
        sent_packed = nn.utils.rnn.pack_padded_sequence(sent, sent_len_sorted)
        sent_output = self.enc_lstm(sent_packed)[0]  # seqlen x batch x 2*nhid
        sent_output = nn.utils.rnn.pad_packed_sequence(sent_output)[0]

        # Un-sort by length
        idx_unsort = torch.from_numpy(idx_unsort).cuda() if self.is_cuda() \
            else torch.from_numpy(idx_unsort)
        sent_output = sent_output.index_select(1, idx_unsort)

        # Pooling
        if self.pool_type == "mean":
            sent_len = torch.FloatTensor(sent_len.copy()).unsqueeze(1).cuda()
            emb = torch.sum(sent_output, 0).squeeze(0)
            emb = emb / sent_len.expand_as(emb)
        elif self.pool_type == "max":
            if not self.max_pad:
                sent_output[sent_output == 0] = -1e9
            emb = torch.max(sent_output, 0)[0]
            if emb.ndimension() == 3:
                emb = emb.squeeze(0)
                assert emb.ndimension() == 2

        return emb

    def set_w2v_path(self, w2v_path):
        self.w2v_path = w2v_path

    def get_word_dict(self, sentences, tokenize=True):
        # create vocab of words
        word_dict = {}
        sentences = [s.split() if not tokenize else self.tokenize(s) for s in sentences]
        for sent in sentences:
            for word in sent:
                if word not in word_dict:
                    word_dict[word] = ''
        word_dict[self.bos] = ''
        word_dict[self.eos] = ''
        return word_dict

    def get_w2v(self, word_dict):
        assert hasattr(self, 'w2v_path'), 'w2v path not set'
        # create word_vec with w2v vectors
        word_vec = {}
        with open(self.w2v_path, encoding='utf-8') as f:
            for line in f:
                word, vec = line.split(' ', 1)
                if word in word_dict:
                    word_vec[word] = np.fromstring(vec, sep=' ')
        print('Found %s(/%s) words with w2v vectors' % (len(word_vec), len(word_dict)))
        return word_vec

    def get_w2v_k(self, K):
        assert hasattr(self, 'w2v_path'), 'w2v path not set'
        # create word_vec with k first w2v vectors
        k = 0
        word_vec = {}
        with open(self.w2v_path, encoding='utf-8') as f:
            for line in f:
                word, vec = line.split(' ', 1)
                if k <= K:
                    word_vec[word] = np.fromstring(vec, sep=' ')
                    k += 1
                if k > K:
                    if word in [self.bos, self.eos]:
                        word_vec[word] = np.fromstring(vec, sep=' ')

                if k > K and all([w in word_vec for w in [self.bos, self.eos]]):
                    break
        return word_vec

    def build_vocab(self, sentences, tokenize=True):
        assert hasattr(self, 'w2v_path'), 'w2v path not set'
        word_dict = self.get_word_dict(sentences, tokenize)
        self.word_vec = self.get_w2v(word_dict)
        print('Vocab size : %s' % (len(self.word_vec)))

    # build w2v vocab with k most frequent words
    def build_vocab_k_words(self, K):
        assert hasattr(self, 'w2v_path'), 'w2v path not set'
        self.word_vec = self.get_w2v_k(K)
        print('Vocab size : %s' % (K))

    def update_vocab(self, sentences, tokenize=True):
        assert hasattr(self, 'w2v_path'), 'warning : w2v path not set'
        assert hasattr(self, 'word_vec'), 'build_vocab before updating it'
        word_dict = self.get_word_dict(sentences, tokenize)

        # keep only new words
        for word in self.word_vec:
            if word in word_dict:
                del word_dict[word]

        # udpate vocabulary
        if word_dict:
            new_word_vec = self.get_w2v(word_dict)
            self.word_vec.update(new_word_vec)
        else:
            new_word_vec = []
        print('New vocab size : %s (added %s words)'% (len(self.word_vec), len(new_word_vec)))

    def get_batch(self, batch):
        # sent in batch in decreasing order of lengths
        # batch: (bsize, max_len, word_dim)
        embed = np.zeros((len(batch[0]), len(batch), self.word_emb_dim))

        for i in range(len(batch)):
            for j in range(len(batch[i])):
                embed[j, i, :] = self.word_vec[batch[i][j]]

        return torch.FloatTensor(embed)

    def tokenize(self, s):
        from nltk.tokenize import word_tokenize
        if self.moses_tok:
            s = ' '.join(word_tokenize(s))
            s = s.replace(" n't ", "n 't ")  # HACK to get ~MOSES tokenization
            return s.split()
        else:
            return word_tokenize(s)

    def prepare_samples(self, sentences, bsize, tokenize, verbose):
        sentences = [[self.bos] + s.split() + [self.eos] if not tokenize else
                     [self.bos] + self.tokenize(s) + [self.eos] for s in sentences]
        n_w = np.sum([len(x) for x in sentences])

        # filters words without w2v vectors
        for i in range(len(sentences)):
            s_f = [word for word in sentences[i] if word in self.word_vec]
            if not s_f:
                import warnings
                warnings.warn('No words in "%s" (idx=%s) have w2v vectors. \
                               Replacing by "</s>"..' % (sentences[i], i))
                s_f = [self.eos]
            sentences[i] = s_f

        lengths = np.array([len(s) for s in sentences])
        n_wk = np.sum(lengths)
        if verbose:
            print('Nb words kept : %s/%s (%.1f%s)' % (
                        n_wk, n_w, 100.0 * n_wk / n_w, '%'))

        # sort by decreasing length
        lengths, idx_sort = np.sort(lengths)[::-1], np.argsort(-lengths)
        sentences = np.array(sentences)[idx_sort]

        return sentences, lengths, idx_sort

    def encode(self, sentences, bsize=64, tokenize=True, verbose=False):
        tic = time.time()
        sentences, lengths, idx_sort = self.prepare_samples(
                        sentences, bsize, tokenize, verbose)

        embeddings = []
        for stidx in range(0, len(sentences), bsize):
            batch = self.get_batch(sentences[stidx:stidx + bsize])
            if self.is_cuda():
                batch = batch.cuda()
            with torch.no_grad():
                batch = self.forward((batch, lengths[stidx:stidx + bsize])).data.cpu().numpy()
            embeddings.append(batch)
        embeddings = np.vstack(embeddings)

        # unsort
        idx_unsort = np.argsort(idx_sort)
        embeddings = embeddings[idx_unsort]

        if verbose:
            print('Speed : %.1f sentences/s (%s mode, bsize=%s)' % (
                    len(embeddings)/(time.time()-tic),
                    'gpu' if self.is_cuda() else 'cpu', bsize))
        return embeddings

    def visualize(self, sent, tokenize=True):

        sent = sent.split() if not tokenize else self.tokenize(sent)
        sent = [[self.bos] + [word for word in sent if word in self.word_vec] + [self.eos]]

        if ' '.join(sent[0]) == '%s %s' % (self.bos, self.eos):
            import warnings
            warnings.warn('No words in "%s" have w2v vectors. Replacing \
                           by "%s %s"..' % (sent, self.bos, self.eos))
        batch = self.get_batch(sent)

        if self.is_cuda():
            batch = batch.cuda()
        output = self.enc_lstm(batch)[0]
        output, idxs = torch.max(output, 0)
        # output, idxs = output.squeeze(), idxs.squeeze()
        idxs = idxs.data.cpu().numpy()
        argmaxs = [np.sum((idxs == k)) for k in range(len(sent[0]))]

        # visualize model
        import matplotlib.pyplot as plt
        x = range(len(sent[0]))
        y = [100.0 * n / np.sum(argmaxs) for n in argmaxs]
        plt.xticks(x, sent[0], rotation=45)
        plt.bar(x, y)
        plt.ylabel('%')
        plt.title('Visualisation of words importance')
        plt.show()

        return output, idxs

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/ananya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# (Technical stuff to load in and train the InferSent model)

# %%
V = 2
MODEL_PATH = 'encoder/infersent%s.pkl' % V
params_model = {'bsize': 64, 'word_emb_dim': 300, 'enc_lstm_dim': 2048,
                'pool_type': 'max', 'dpout_model': 0.0, 'version': V}
infersent = InferSent(params_model)
infersent.load_state_dict(torch.load(MODEL_PATH))
# Out:
# <All keys matched successfully>

# %%
W2V_PATH = 'fastText/crawl-300d-2M.vec'
infersent.set_w2v_path(W2V_PATH)

# %% [markdown]
# ## Read in Data

# %%
f = open("/Users/ananya/Desktop/OneDrive/Ananya/FALL_2021/NLP/QA-data/set1/a6.txt","r", encoding="utf-8")
data = f.read()

# %% [markdown]
# ## Use TextBlob to Separate Text into Sentences

# %%
blob = TextBlob(data)
sentences = [item.raw for item in blob.sentences]

# %% [markdown]
# ## Build Vocabulary from Text using InferSent

# %%
infersent.build_vocab(sentences, tokenize=True)
# Out:
# Found 3054(/3171) words with w2v vectors
# Vocab size : 3054

# %% [markdown]
# ## Use InferSent Model to Create Embedding Vectors for Sentences

# %%
dict_embeddings = {}
for i in range(len(sentences)):
    if (i%50 == 0):
        print(i)
    dict_embeddings[sentences[i]] = infersent.encode([sentences[i]], tokenize=True)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500

# %%
d1 = {key:dict_embeddings[key] for i, key in enumerate(dict_embeddings) if i % 2 == 0}
# Out:
# {'David Beckham\n\n\nDavid Robert Joseph Beckham, OBE (/ˈbɛkəm/; born 2 May 1975) is an English former professional footballer.': array([[0.00746889, 0.1223213 , 0.09539797, ..., 0.03934553, 0.05088743,
#          0.01157315]], dtype=float32),
#  'He is the first English player to win league titles in four countries: England, Spain, the United States and France.': array([[0.00746889, 0.01175361, 0.04921962, ..., 0.11515987, 0.015773  ,
#          0.00014959]], dtype=float32),
#  "Known for his range of passing, crossing ability and bending free-kicks, he was twice runner-up for FIFA World Player of the Year and in 2004 he was named in the FIFA 100 list of the world's greatest living players.": array([[0.00746889, 0.03998165, 0.12369049, ..., 0.1121926 , 0.09445508,
#          0.0146687 ]], dtype=float32),
#  'With United, he won the Premier League title six times, the FA Cup twice, and the UEFA Champions League in 1999.': array([[ 0.00746889,  0.02053733,  0.09515812, ...,  0.07737068,
#           0.01681741, -0.00295624]], dtype=float32),
#  'In July 2007 Beckham signed a five-year contract with Major League Soccer club LA Galaxy.': array([[ 0.00746889, -0.0117227 ,  0.06583399, ...,  0.04239219,
#           0.09721927,  0.03986535]], dtype=float32),
#  'He was the first British footballer to play 100 UEFA Champions League games.': array([[ 0.00746889,  0.0144011 ,  0.0829064 , ...,  0.05668119,
#           0.08601342, -0.01028704]], dtype=float32),
#  'He was captain for six years, earning 58 caps during his tenure.': array([[ 0.00746889,  0.0304058 ,  0.04445706, ...,  0.06648185,
#           0.01800982, -0.0138564 ]], dtype=float32),
#  'One of the most marketable athletes in sport, Beckham has consistently ranked among the highest earners in football, and in 2013 he was listed as the highest-paid player in the world, earning over $50 million in the previous 12 months.': array([[0.00746889, 0.02633968, 0.11863715, ..., 0.06400339, 0.06175374,
#          0.0106392 ]], dtype=float32),
#  'He has been a UNICEF UK ambassador since 2005, and in 2015 he launched 7: The David Beckham UNICEF Fund to help protect children in danger around the world.': array([[0.00746889, 0.07113035, 0.11103337, ..., 0.09663229, 0.03254224,
#          0.01171433]], dtype=float32),
#  'Early lifeEdit\nBeckham was born at Whipps Cross University Hospital in Leytonstone, London, England.': array([[ 0.00746889, -0.01766351,  0.09568461, ...,  0.03585747,
#           0.0338626 ,  0.02583458]], dtype=float32),
#  '1949), a hairdresser, and David Edward Alan "Ted" Beckham (b. Edmonton, London, July–September 1948), a kitchen fitter, who married at the London Borough of Hackney in 1969.': array([[0.00746889, 0.08871742, 0.12079655, ..., 0.05212628, 0.05767759,
#          0.0038374 ]], dtype=float32),
#  'He regularly played football in Ridgeway Park, Chingford, as a child, and attended Chase Lane Primary School and Chingford County High School.': array([[ 0.00746889,  0.05201534,  0.0944156 , ...,  0.08427466,
#          -0.03756654, -0.00303203]], dtype=float32),
#  "I'd say, 'I want to be a footballer.'": array([[ 0.00746889,  0.0048752 , -0.01818343, ...,  0.08854943,
#          -0.0048693 , -0.00287376]], dtype=float32),
#  'But that was the only thing I ever wanted to do."': array([[ 0.00746889, -0.03177233, -0.00549801, ...,  0.02666986,
#          -0.02528132, -0.00879386]], dtype=float32),
#  'In his book Both Feet on the Ground, he stated that growing up he attended church every week with his parents, because that was the only way he could play football for their team.': array([[ 0.00746889,  0.05170212,  0.09021003, ...,  0.09130402,
#          -0.01652335, -0.01120896]], dtype=float32),
#  "David inherited his parents' love of Manchester United, and his main sporting passion was football.": array([[ 0.00746889,  0.09828709,  0.16479969, ...,  0.07773872,
#           0.03100784, -0.01385639]], dtype=float32),
#  'He played for a local youth team called Ridgeway Rovers – coached by his father, Stuart Underwood and Steve Kirby.': array([[0.00746889, 0.1780525 , 0.05887472, ..., 0.05065462, 0.01865279,
#          0.00136026]], dtype=float32),
#  "Young Beckham had trials with his local club Leyton Orient, Norwich City and attended Tottenham Hotspur's school of excellence.": array([[0.00746889, 0.02941974, 0.15377976, ..., 0.0362439 , 0.01425557,
#          0.02812903]], dtype=float32),
#  "During a two-year period in which Beckham played for Brimsdown Rovers' youth team, he was named Under-15 Player of the Year in 1990.": array([[ 0.00746889,  0.00083857,  0.04020623, ...,  0.04895214,
#          -0.00355634,  0.00261364]], dtype=float32),
#  'Club careerEdit\n\n\nManchester UnitedEdit\n\n\nYouth and early careerEdit\nHaving signed for Manchester United as a trainee on 8 July 1991, Beckham was part of a group of young players, including Ryan Giggs, Gary Neville, Phil Neville, Nicky Butt and Paul Scholes, who were coached by Eric Harrison, and helped the club win the FA Youth Cup in May 1992.': array([[0.00746889, 0.08765985, 0.10605545, ..., 0.07068339, 0.03952627,
#          0.03929404]], dtype=float32),
#  "Beckham scored Manchester United's second goal in the 30th minute of their 3–1 first-leg win of the final against Crystal Palace on 14 April 1992.": array([[ 0.00746889, -0.03104855,  0.10436085, ...,  0.04361456,
#           0.05039401,  0.02777356]], dtype=float32),
#  "Beckham's impact led to a first-team debut on 23 September 1992, as a substitute for Andrei Kanchelskis in a League Cup match against Brighton & Hove Albion.": array([[0.00746889, 0.01125486, 0.07875619, ..., 0.08385521, 0.03126105,
#          0.03516972]], dtype=float32),
#  'Manchester United would again reach the final of the FA Youth Cup, where they would face Leeds United.': array([[ 0.00746889, -0.04108567,  0.01436935, ...,  0.03876092,
#           0.02339735,  0.02076693]], dtype=float32),
#  "In the second leg on 13 May 1993, Beckham played the entire fixture of Manchester United's 2–1 defeat, which gave Leeds United a 4–1 aggregate score.": array([[ 0.00746889, -0.04963772,  0.11627482, ...,  0.05332805,
#           0.04237962,  0.01393604]], dtype=float32),
#  "In September 1994, Beckham went on to gain his first full appearance in the club's first team against Port Vale in a League Cup fixture.": array([[0.00746889, 0.03483947, 0.01036573, ..., 0.05980744, 0.02994285,
#          0.03308779]], dtype=float32),
#  'However, despite the victory they finished third out of four in their group behind FC Barcelona.': array([[ 0.00746889, -0.06645802,  0.03677636, ...,  0.00855262,
#           0.03152095, -0.00725258]], dtype=float32),
#  'He impressed, scoring two goals in five appearances, notably scoring directly from a corner kick.': array([[ 0.00746889,  0.01175361,  0.15658838, ...,  0.08688633,
#           0.0274905 , -0.00362617]], dtype=float32),
#  'He played four times for United in the league that season, as they finished second behind Blackburn Rovers and missed a third successive Premier League title by a single point.': array([[ 0.00746889,  0.01175361,  0.08160824, ...,  0.11968557,
#           0.03421437, -0.00043621]], dtype=float32),
#  "United manager Sir Alex Ferguson had a great deal of confidence in the club's young players.": array([[0.00746889, 0.11085978, 0.15048562, ..., 0.04989691, 0.01639196,
#          0.00216947]], dtype=float32),
#  'When experienced players Paul Ince, Mark Hughes, and Andrei Kanchelskis left the club after the end of the 1994–95 season, his decision to let youth team players replace them instead of buying star players from other clubs (United had been linked with moves for players including Darren Anderton, Marc Overmars, and Roberto Baggio, but no major signings were made that summer), drew a great deal of criticism.': array([[0.00746889, 0.09932584, 0.14765264, ..., 0.07436101, 0.01351179,
#          0.02594838]], dtype=float32),
#  "Beckham swiftly established himself as United's right-sided midfielder (rather than a right-winger in the style of his predecessor Andrei Kanchelskis) and helped them to win the Premier League title and FA Cup double that season, scoring the winner in the semi-final against Chelsea and also provided the corner that Eric Cantona scored from in the FA Cup Final.": array([[0.00746889, 0.04649878, 0.11012593, ..., 0.07407629, 0.07129418,
#          0.02705008]], dtype=float32),
#  'Despite playing regularly (and to a consistently high standard) for Manchester United, Beckham did not break into the England squad before Euro 96.': array([[ 0.00746889, -0.04614843,  0.04434145, ...,  0.06192132,
#           0.07857472,  0.01564093]], dtype=float32),
#  'On 17 August 1996 (the first day of the Premier League season), Beckham became something of a household name when he scored a spectacular goal in a match against Wimbledon.': array([[ 0.00746889, -0.00053432,  0.11699752, ...,  0.08818511,
#           0.03263782,  0.04008646]], dtype=float32),
#  'When Beckham scored his famous goal, he did so in Adidas Predator shoes custom-made for Charlie Miller ("Charlie" embroidered on boots), which had been given to Beckham by mistake.': array([[0.00746889, 0.04406385, 0.13419726, ..., 0.09725884, 0.0898295 ,
#          0.03071971]], dtype=float32),
#  'During the 1996–97 season, Beckham became an automatic first-choice player at Manchester United helping them to retain the Premier League championship, and was voted PFA Young Player of the Year by his peers.': array([[0.00746889, 0.03240272, 0.14157206, ..., 0.08100751, 0.0406625 ,
#          0.00054668]], dtype=float32),
#  'Manchester United started the 1997–98 season well but erratic performances in the second half of the season saw United finish second behind Arsenal.': array([[ 0.00746889, -0.08318288,  0.06114862, ...,  0.07121512,
#           0.03702172,  0.01551553]], dtype=float32),
#  'There had been speculation that the criticism that he had received after being sent off in the World Cup would lead to him leaving England, but Beckham decided to stay at Manchester United.': array([[ 0.00746889,  0.00103658,  0.02778834, ...,  0.08377215,
#           0.0411607 , -0.00228709]], dtype=float32),
#  'Beckham scored the equaliser with a curling strike from 25 yards out into the top left corner of the goal and United went on to win the match and the league.': array([[ 0.00746889, -0.03339016,  0.11966991, ...,  0.07737414,
#           0.03754294,  0.02027767]], dtype=float32),
#  'United were losing the match 1–0 at the end of normal time, but won the trophy by scoring two goals in injury time.': array([[ 0.00746889, -0.00489255,  0.09921872, ...,  0.02845859,
#           0.00839531, -0.01385639]], dtype=float32),
#  "Those crucial assists, coupled with great performances over the rest of the season, led to him finishing runner up to Rivaldo for 1999's European Footballer of the Year and FIFA World Player of the Year awards.": array([[0.00746889, 0.01094835, 0.1737715 , ..., 0.08144373, 0.00268033,
#          0.00084777]], dtype=float32),
#  "It was suggested in the press that his wife was a bad influence on him, and that it might be in United's interests to sell him, but his manager publicly backed him and he stayed at the club.": array([[ 0.00746889,  0.08505259,  0.06471261, ...,  0.07011452,
#           0.01767574, -0.00764082]], dtype=float32),
#  'Beckham helped United retain the Premier League title in 1999–2000 by an 18-point margin – after being pushed by Arsenal and Leeds United for much of the season.': array([[ 7.4688885e-03, -3.7779313e-02,  1.0541382e-01, ...,
#           5.3655043e-02,  4.6323933e-02,  6.7475405e-05]], dtype=float32),
#  "By the early 2000s, the relationship between Ferguson and Beckham had begun to deteriorate, possibly as a result of Beckham's fame and commitments away from football.": array([[0.00746889, 0.01355798, 0.03765697, ..., 0.0667662 , 0.0573254 ,
#          0.01079276]], dtype=float32),
#  "He responded by fining Beckham the maximum amount that was permitted (two weeks' wages – then £50,000) and dropping him for a crucial match against United's rivals Leeds United.": array([[0.00746889, 0.0256899 , 0.04967164, ..., 0.06525131, 0.03617444,
#          0.01170903]], dtype=float32),
#  '"He was never a problem until he got married.': array([[ 0.00746889,  0.01175361, -0.00282232, ...,  0.06664293,
#          -0.0202256 , -0.0138564 ]], dtype=float32),
#  'Getting married into that entertainment scene was a difficult thing – from that moment, his life was never going to be the same.': array([[ 0.00746889,  0.0198532 ,  0.08514979, ...,  0.02887923,
#          -0.01073509, -0.01385639]], dtype=float32),
#  "– Alex Ferguson speaking about Beckham's marriage in 2007.": array([[ 0.00746889,  0.02053513,  0.09709586, ...,  0.02738799,
#           0.05044235, -0.00055727]], dtype=float32),
#  'He scored nine goals that season, all in the Premier League.': array([[0.00746889, 0.01175361, 0.11699142, ..., 0.07299992, 0.01217076,
#          0.01871629]], dtype=float32),
#  "There was speculation in the British media that the injury might have been caused deliberately, as the player who had injured Beckham was Argentine Aldo Duscher, and England and Argentina were due to meet in that year's World Cup.": array([[0.00746889, 0.04602982, 0.07818581, ..., 0.08649532, 0.05124671,
#          0.00233582]], dtype=float32),
#  'The income from his new contract, and his many endorsement deals, made him the highest-paid player in the world at the time.': array([[0.00746889, 0.04576826, 0.05500933, ..., 0.05168945, 0.03573425,
#          0.02181481]], dtype=float32),
#  'Following an injury early in the 2002–03 season, Beckham was unable to regain his place on the Manchester United team, with Ole Gunnar Solskjær having replaced him on the right side of midfield.': array([[ 0.00746889,  0.0332908 ,  0.06224934, ...,  0.05226542,
#           0.0395415 , -0.00671851]], dtype=float32),
#  'The incident led to a great deal of transfer speculation involving Beckham, with bookmakers offering odds on whether he or Ferguson would be first to leave the club.': array([[0.00746889, 0.01907626, 0.14679816, ..., 0.07387718, 0.0486499 ,
#          0.00821315]], dtype=float32),
#  'He was still a first-choice player for England, however, and was appointed an Officer of the Most Excellent Order of the British Empire (OBE) for services to football on 13 June 2003.': array([[0.00746889, 0.02199667, 0.15840766, ..., 0.06868976, 0.01404668,
#          0.02509122]], dtype=float32),
#  'He also made 81 Champions league appearances, scoring 15 goals.': array([[0.00746889, 0.01175361, 0.06840158, ..., 0.11111756, 0.05352249,
#          0.01382755]], dtype=float32),
#  'By this stage, he was their joint second longest serving player behind Ryan Giggs (having joined them at the same time as Nicky Butt, Gary Neville and Paul Scholes).': array([[0.00746889, 0.08861054, 0.02141216, ..., 0.06418572, 0.04045826,
#          0.02152207]], dtype=float32),
#  'Beckham was the latest signing in the Galácticos era of global stars signed by club president Florentino Pérez every summer.': array([[0.00746889, 0.02943593, 0.14521798, ..., 0.06468057, 0.04184087,
#          0.0148044 ]], dtype=float32),
#  'Though announced in mid-June, the transfer was completed on 1 July 2003, making him the third Englishman to play for the club after Laurie Cunningham and Steve McManaman.': array([[ 0.00746889,  0.08969375,  0.1156754 , ...,  0.03976213,
#          -0.0152985 ,  0.02510419]], dtype=float32),
#  'Although Beckham had worn the number seven shirt for Manchester United and England, he was unable to wear it at Madrid as it was currently assigned to club captain Raúl.': array([[0.00746889, 0.00529233, 0.02944862, ..., 0.06909172, 0.02739522,
#          0.00206691]], dtype=float32),
#  "In the week before Beckham presentation, Real named Carlos Queiroz as their new head coach, meaning that Beckham got reunited with a familiar face upon arriving to Madrid since Queiroz spent the previous season as Alex Ferguson's assistant at Manchester United.": array([[0.00746889, 0.0344376 , 0.12369129, ..., 0.0704468 , 0.0411607 ,
#          0.00930692]], dtype=float32),
#  "Real's brand recognition in that part of the globe was already well established as the club made financially successful trips to Asia during previous off-seasons; however, the presence of global marketing icon such as Beckham made this particular tour a financial smash for los Merengues.": array([[0.00746889, 0.03810085, 0.11690482, ..., 0.08351816, 0.05056017,
#          0.04198473]], dtype=float32),
#  'Beckham signed on with Simon Fuller and his company 19 Entertainment that already managed the career of Victoria.': array([[0.00746889, 0.03040563, 0.07612393, ..., 0.0460784 , 0.02781311,
#          0.0120236 ]], dtype=float32),
#  'In late August 2003, Real Madrid won the Spanish Super Cup over two legs versus RCD Mallorca, with Beckham scoring the final goal in a 3–0 return leg win at home, thus setting the stage for the start of the league season.': array([[0.00746889, 0.05587118, 0.05744257, ..., 0.11852396, 0.05392182,
#          0.02652934]], dtype=float32),
#  'Queiroz mostly favoured the adaptable 5–3–2 formation with two fullbacks Michel Salgado and Roberto Carlos often joining the attack down the wings, while Beckham played on the right of the three-man midfield alongside Zidane and Figo.': array([[ 0.00746889,  0.09176073,  0.12101644, ...,  0.04858473,
#           0.02525292, -0.01385639]], dtype=float32),
#  'In July 2004, while Beckham was in pre-season training in Spain, an intruder scaled a wall at the Beckham home while carrying a can of petrol.': array([[0.00746889, 0.02568566, 0.01996717, ..., 0.06294549, 0.07123197,
#          0.04188672]], dtype=float32),
#  'The league season began with new head coach José Antonio Camacho behind the bench, but he ended up lasting only three matches, handing in his resignation as Real dropped to eighth spot in the La Liga standings.': array([[ 0.00746889,  0.10866664,  0.0637898 , ...,  0.13317096,
#           0.03106852, -0.00750231]], dtype=float32),
#  'Beckham made more headlines on 9 October 2004 when he admitted intentionally fouling Ben Thatcher in an England match against Wales to get himself booked.': array([[0.00746889, 0.03260102, 0.04994715, ..., 0.0958225 , 0.04213129,
#          0.02114159]], dtype=float32),
#  'The Football Association asked Beckham for an explanation of his actions and he admitted that he had "made a mistake" and apologised.': array([[0.00746889, 0.042472  , 0.03941575, ..., 0.08779681, 0.04459623,
#          0.02603734]], dtype=float32),
#  'Having received a yellow card, he was judged to have sarcastically applauded the referee and was given a second yellow card, causing an automatic dismissal, although the suspension was cancelled on appeal.': array([[0.00746889, 0.01268942, 0.16239373, ..., 0.05597682, 0.00438485,
#          0.01861904]], dtype=float32),
#  'However, the well-traveled Brazilian failed to inspire the team to the title as Real again finished the season in the runner-up spot.': array([[ 0.00746889,  0.01642578,  0.02498219, ...,  0.00179604,
#           0.05767892, -0.00229149]], dtype=float32),
#  'One day later Luxemburgo got the axe and was replaced with Juan Ramón López Caro.': array([[0.00746889, 0.04604487, 0.03919181, ..., 0.01668677, 0.00644153,
#          0.00449672]], dtype=float32),
#  'During the season, Beckham established football academies in Los Angeles and east London and he was named a judge for the 2006 British Book Awards.': array([[ 0.00746889,  0.03386931,  0.11469293, ...,  0.07610152,
#           0.09693927, -0.00625233]], dtype=float32),
#  'The season also marked the end of an era for the club as Pérez resigned his president post in January 2006 with Vicente Boluda named as replacement on interim basis until the end of the season.': array([[ 0.00746889,  0.0372967 ,  0.03234093, ...,  0.07929091,
#          -0.00338932,  0.02744805]], dtype=float32),
#  'Ramón Calderón became the new Real president.': array([[ 0.00746889,  0.03833865,  0.05495128, ...,  0.04968532,
#          -0.00121714, -0.00533061]], dtype=float32),
#  'Initially out of favour with newly arrived head coach Fabio Capello, Beckham started only a few games at the beginning of the season, as the speedier José Antonio Reyes was normally preferred on the right wing.': array([[0.00746889, 0.13645904, 0.10996356, ..., 0.06409442, 0.02978607,
#          0.00989324]], dtype=float32),
#  "On 10 January 2007, after prolonged contract negotiations, Real Madrid's sporting director Predrag Mijatović announced that Beckham would not remain at Real Madrid after the end of the season.": array([[0.00746889, 0.11337333, 0.07972616, ..., 0.04031758, 0.04010958,
#          0.03762482]], dtype=float32),
#  'On 11 January 2007, Beckham announced that he had signed a five-year deal to play for LA Galaxy beginning 1 July 2007.': array([[0.00746889, 0.00854943, 0.0716454 , ..., 0.09376723, 0.07467201,
#          0.03358637]], dtype=float32),
#  'A few days later while speaking to the students at Villanueva University Center in Madrid, Calderón said that Beckham is "going to Hollywood to be half a film star", adding "our technical staff were right not to extend his contract, which has been proved by the fact that no other technical staff in the world wanted him except Los Angeles".': array([[0.00746889, 0.03179633, 0.10926251, ..., 0.04487985, 0.11197248,
#          0.01066021]], dtype=float32),
#  "The player immediately repaid his head coach's trust by scoring the equalising goal from a 27-yard free kick as Real Madrid eventually recorded a 2–1 victory.": array([[ 0.00746889,  0.05454407,  0.13801514, ...,  0.0762471 ,
#           0.01469474, -0.00387034]], dtype=float32),
#  'Beckham played a pivotal role in all three Madrid goals in the home game, with Bayern goalkeeper Oliver Khan describing his performance as "world class".': array([[0.00746889, 0.03407757, 0.07448266, ..., 0.06235337, 0.02752381,
#          0.00631659]], dtype=float32),
#  "With Real down 0–1 Beckham limped off the field and was replaced by José Antonio Reyes who scored two goals leading the team to that season's La Liga title, their first since Beckham had signed with them and 30th overall in the club's history.": array([[0.00746889, 0.11246967, 0.09213182, ..., 0.08811413, 0.04216166,
#          0.02922465]], dtype=float32),
#  "With his wife and children along with celebrity friends Tom Cruise and Katie Holmes watching from a luxury box at Bernabeu Stadium, it was only Beckham's second piece of silverware since he joined the famous club.": array([[0.00746889, 0.10998497, 0.10801469, ..., 0.06292613, 0.09513024,
#          0.0090462 ]], dtype=float32),
#  "Several weeks before Beckham's scheduled arrival to the United States, Real's management contacted LA Galaxy's ownership group about reacquiring the player, but were quickly turned down.": array([[0.00746889, 0.0321253 , 0.04034989, ..., 0.06720037, 0.07234214,
#          0.00598428]], dtype=float32),
#  "LA GalaxyEdit\n\nBeckham's involvement with Major League Soccer began while he was still a Real Madrid player when it was confirmed on 11 January 2007 that he would be leaving Madrid in six months to join MLS side LA Galaxy.": array([[0.00746889, 0.00398166, 0.02379094, ..., 0.08327495, 0.10159192,
#          0.00494904]], dtype=float32),
#  'The announcement made top news all across the globe.': array([[ 0.00746889, -0.04439976,  0.10219146, ..., -0.0092248 ,
#           0.06427156,  0.04134796]], dtype=float32),
#  'To maximise the media effect, in the press release they decided to list the potential sum that Beckham could make over the 5-year period from all his revenue sources, which in addition to his Galaxy pay also include his personal endorsements.': array([[0.00746889, 0.03880326, 0.08804699, ..., 0.05642841, 0.04418863,
#          0.00705373]], dtype=float32),
#  'The high-profile acquisition paid immediate financial dividends for Galaxy long before Beckham joined the team.': array([[ 0.00746889, -0.0171499 ,  0.08400518, ..., -0.01174461,
#           0.02554994,  0.0205672 ]], dtype=float32),
#  "The gate revenue peaked as well with 11,000 new season tickets holders and sold-out luxury suites (each one of the 42 inside the team's home ground, the Home Depot Center).": array([[ 0.00746889, -0.05765492,  0.14060405, ...,  0.02610373,
#           0.04349492,  0.010331  ]], dtype=float32),
#  'Involved on many business fronts worldwide, AEG was already leveraging its Beckham association in places such as China, where the company had been working aggressively in Shanghai and Beijing for years to receive clearance to build arenas and stadiums.': array([[ 0.00746889, -0.04639424,  0.09495949, ...,  0.04091733,
#           0.06853469,  0.03920464]], dtype=float32),
#  "In the months following the announcement, the additional terms of Beckham's contract became public knowledge.": array([[ 0.00746889, -0.05711504,  0.08150633, ...,  0.0272148 ,
#           0.03759512,  0.0108934 ]], dtype=float32),
#  'Another provision was the opt-out clause after the 2009 season, meaning that should he decide so, Beckham was free to leave the club after completing year three of his 5-year contract.': array([[0.00746889, 0.02404568, 0.14540233, ..., 0.07580455, 0.04391751,
#          0.00673209]], dtype=float32),
#  "Beckham's contract with LA Galaxy took effect on 11 July, and on 13 July, the famous Englishman was officially unveiled as a Galaxy player at the Home Depot Center to much fanfare and world media interest in front of more than 5,000 gathered fans and some 700 accredited media members.": array([[0.00746889, 0.09241471, 0.12380455, ..., 0.05036242, 0.08225261,
#          0.02966709]], dtype=float32),
#  'It was announced that Galaxy jersey sales had already reached a record figure of over 250,000 prior to this formal introduction.': array([[ 0.00746889, -0.08249062,  0.10149506, ...,  0.08062392,
#           0.02209682,  0.04512668]], dtype=float32),
#  'He made the cover of Sports Illustrated, a few weeks earlier Adidas launched the extensive 13-part ad campaign "Fútbol meets Football" starring Beckham and NFL running back Reggie Bush, and W magazine published a racy photo spread featuring David and wife Victoria photographed by Steven Klein.': array([[0.00746889, 0.08754725, 0.11444496, ..., 0.04102822, 0.05998075,
#          0.02195472]], dtype=float32),
#  "In addition to popularising soccer, Beckham's arrival was used as platform for entertainment industry endeavours.": array([[ 0.00746889, -0.05258989,  0.11139236, ...,  0.07110636,
#           0.02600638,  0.00655102]], dtype=float32),
#  'On 16 July, CAA had hosted a welcoming bash for David at its new eight-storey, $400 million headquarters in Century City with CAA employees reportedly instructed beforehand to line the staircase and clap for Beckham upon his arrival.': array([[0.00746889, 0.06288378, 0.13700782, ..., 0.02639874, 0.05941299,
#          0.03029137]], dtype=float32),
#  "On Saturday afternoon, 21 July, despite still nursing the injured left ankle that he picked up a month earlier during the final match of La Liga's season, Beckham made his Galaxy debut, coming on for Alan Gordon in the 78th minute of a 0–1 friendly loss to Chelsea as part of the World Series of Soccer.": array([[0.00746889, 0.04550129, 0.09713687, ..., 0.10229658, 0.04229016,
#          0.0220394 ]], dtype=float32),
#  'However, the proceedings on the field of play completely took a back seat to the Beckham spectacle, and despite the presence of worldwide football stars Andriy Shevchenko, Didier Drogba, Michael Ballack, Frank Lampard, and John Terry, the US television cameras were firmly focused on Beckham who spent most of the match on the bench.': array([[0.00746889, 0.08761281, 0.11149835, ..., 0.06329467, 0.04146225,
#          0.01712868]], dtype=float32),
#  "Though the existing injury was not aggravated too much, Beckham's recovery process was set back by about a week.": array([[ 0.00746889, -0.06383789,  0.06820961, ...,  0.02312867,
#           0.03595713, -0.00233436]], dtype=float32),
#  "For comparison ESPN2's weekly MLS broadcasts on Thursdays drew a consistent 0.2 rating on virtually no promotion while Freddy Adu's MLS debut televised on ABC back in 2004 earned a 1.3 rating.": array([[0.00746889, 0.01634068, 0.10741579, ..., 0.12771451, 0.02099183,
#          0.01305394]], dtype=float32),
#  "The day after the made-for-TV debut was reserved for the welcoming party for the Beckhams at LA's Museum of Contemporary Art, formally billed as being hosted by Tom Cruise, Katie Holmes, Will Smith, and Jada Pinkett Smith though in actuality a CAA-organized event.": array([[0.00746889, 0.1052921 , 0.14368683, ..., 0.01309929, 0.072903  ,
#          0.00061032]], dtype=float32),
#  'Beckham missed the next four LA Galaxy matches – three in the North American SuperLiga and an MLS game away at Toronto FC though he still made the trip with his teammates, sitting on the bench in street clothes.': array([[0.00746889, 0.02838847, 0.04561464, ..., 0.11243395, 0.06944168,
#          0.02220931]], dtype=float32),
#  'Due to security concerns, it was the first time the team flew on a charter for a road match, rather than flying commercial (MLS normally forbids charter flights for away matches, claiming they provide competitive advantage, but in this case they made an exception due to the frenzy created around Beckham and resulting security issues).': array([[ 0.00746889, -0.03667836,  0.04271638, ...,  0.11957924,
#           0.0485644 ,  0.02017198]], dtype=float32),
#  'Two weeks after his 12-minute appearance vs. Chelsea, still not fully healed Beckham finally made his league debut as a substitute on 9 August away versus DC United in front of the sellout crowd of 46,686 (nearly three times the average DC United home crowd) at the RFK Stadium, coming on for Quavas Kirk in the 71st minute.': array([[0.00746889, 0.03704048, 0.05059563, ..., 0.11562106, 0.07441664,
#          0.0163874 ]], dtype=float32),
#  "He hit a long free kick that Carlos Pavón failed to finish on for the equaliser, and then in the final minutes Beckham served a weighted through ball into Donovan's path that United's keeper Troy Perkins managed to break up in the last moment – the Galaxy lost 1–0.": array([[0.00746889, 0.02725572, 0.14388596, ..., 0.07349925, 0.03412138,
#          0.01459178]], dtype=float32),
#  'Beckham returned to the pitch the following week, again facing DC United, in the SuperLiga semi-final on 15 August.': array([[ 0.00746889, -0.03777931, -0.00363062, ...,  0.03554258,
#           0.02191339,  0.03575989]], dtype=float32),
#  'He also scored his first goal for the team, from a free kick, and also made his first assist, for Landon Donovan in the second half.': array([[0.00746889, 0.05067232, 0.12325714, ..., 0.06943157, 0.00138018,
#          0.02471411]], dtype=float32),
#  'During the SuperLiga final against Pachuca, Beckham injured his right knee, with an MRI scan revealing that he had sprained his medial collateral ligament and would be out for six weeks.': array([[0.00746889, 0.02671589, 0.06592578, ..., 0.08373799, 0.05225732,
#          0.01191558]], dtype=float32),
#  'The Galaxy were eliminated from playoff contention on 21 October, in the final MLS match of the season, a 1–0 loss to the Chicago Fire.': array([[ 0.00746889, -0.05841086,  0.0407437 , ...,  0.09340081,
#           0.02857017,  0.01373607]], dtype=float32),
#  'Beckham trained with Arsenal from 4 January 2008 for three weeks, until he returned to the Galaxy for pre-season training.': array([[ 0.00746889, -0.00362425,  0.10262895, ...,  0.04662396,
#           0.02848811, -0.00158052]], dtype=float32),
#  'On 24 May 2008, the Galaxy defeated the Kansas City Wizards 3–1, giving the Galaxy their first winning record in two years and moving the club into first place in the Western Conference.': array([[ 0.00746889, -0.05727342,  0.08156128, ...,  0.02369484,
#           0.03465451,  0.00976865]], dtype=float32),
#  "The goal marked the second time in Beckham's career that he had scored from his own half, the other being a 1996-goal from the half-way line against Wimbledon at Selhurst Park.": array([[0.00746889, 0.03439986, 0.09692911, ..., 0.08899399, 0.04699894,
#          0.02041713]], dtype=float32),
#  "Milan (loan)Edit\n\nIn 2008, Beckham's success in the England national team under Fabio Capello led to speculation that he might return to Europe to retain match fitness for the World Cup qualifying matches in 2009.": array([[0.00746889, 0.12385154, 0.07750602, ..., 0.08019853, 0.03768105,
#          0.01893001]], dtype=float32),
#  'Despite this and other speculation, Beckham made it clear that the move in no way signalled his intent to leave MLS and announced his intent to return to the Galaxy in time for the start of the 2009 season in March.': array([[0.00746889, 0.03088779, 0.02686553, ..., 0.09631094, 0.03911925,
#          0.00914589]], dtype=float32),
#  "Beckham was unveiled at Milan's training facility by the club's chief executive Adriano Galliani on 20 December 2008.": array([[0.00746889, 0.12435764, 0.05395279, ..., 0.06577332, 0.03308223,
#          0.02717336]], dtype=float32),
#  'After his physical, Beckham was reportedly told by a club doctor that he believed he could continue playing football for another five years, up to the age of 38.': array([[0.00746889, 0.0695225 , 0.04419377, ..., 0.07533784, 0.0429275 ,
#          0.01178333]], dtype=float32),
#  'Afterwards, he and wife Victoria watched from a luxury box as Milan won 5–1.': array([[0.00746889, 0.06743714, 0.1077288 , ..., 0.07130241, 0.01157085,
#          0.02452655]], dtype=float32),
#  'Playing his first competitive match in almost three months, Beckham gave a decent performance in right midfield alongside Pirlo.': array([[0.00746889, 0.07743642, 0.07862187, ..., 0.0657206 , 0.03118285,
#          0.02618269]], dtype=float32),
#  "Going into Beckham's home debut versus Fiorentina a week later, all the talk was around Kaká being the target of a reported £100 million transfer bid by Manchester City.": array([[ 0.00746889, -0.05034277,  0.07153393, ...,  0.07251859,
#           0.0494779 ,  0.04697748]], dtype=float32),
#  'Milan won 1–0 courtesy of Pato, but the 65,000+ San Siro crowd mostly focused on Kaká, imploring him to stay.': array([[0.00746889, 0.09493779, 0.13974987, ..., 0.04098218, 0.06095716,
#          0.01711931]], dtype=float32),
#  'He scored his first goal in Serie A for Milan in a 4–1 victory over Bologna on 25 January, his third appearance for the club.': array([[0.00746889, 0.0560536 , 0.11699142, ..., 0.07668364, 0.00845579,
#          0.03297443]], dtype=float32),
#  'The rumours were confirmed on 4 February, when Beckham stated that he was seeking a permanent transfer to Milan, in a bid to sustain his England career through the 2010 World Cup.': array([[0.00746889, 0.01806585, 0.08916919, ..., 0.09313553, 0.05124672,
#          0.01907386]], dtype=float32),
#  'Still, negotiations continued during a month of speculation.': array([[ 0.00746889, -0.06169234, -0.03268177, ..., -0.00255244,
#          -0.04434213, -0.00063163]], dtype=float32),
#  'This was later confirmed by Beckham, revealing what was described as a unique "timeshare" deal, in which Beckham would play with L.A. from mid-July till the end of the 2009 MLS season.': array([[ 0.00746889, -0.02214428,  0.12100224, ...,  0.12489992,
#           0.09135116,  0.01398305]], dtype=float32),
#  "However, the Galaxy had a much more successful season than in previous years, rising from third to first in the Western Conference during Beckham's time with them.": array([[ 0.00746889, -0.04912233,  0.06109023, ...,  0.065035  ,
#           0.04162432,  0.00346747]], dtype=float32),
#  'In the final on 22 November 2009, the Galaxy lost to Real Salt Lake by 5–4 in a penalty shoot-out after a 1–1 draw.': array([[ 0.00746889,  0.04735717,  0.04510001, ..., -0.01883829,
#          -0.00409673,  0.01691291]], dtype=float32),
#  'Return to Milan (loan)Edit\nIn November 2009, after the end of 2009 MLS season, it was confirmed that Beckham would return to Milan for a second loan period beginning in January 2010.': array([[ 0.00746889, -0.03665061,  0.04698743, ...,  0.13067017,
#           0.02472415,  0.02603621]], dtype=float32),
#  'On 16 February 2010, Beckham played against Manchester United for the first time since he left the club in 2003.': array([[ 0.00746889, -0.00601828,  0.01420428, ...,  0.05017747,
#           0.01775972,  0.00871003]], dtype=float32),
#  'Beckham returned to Old Trafford for the second leg of the tie on 10 March 2010; he did not start the match, but was brought on for Ignazio Abate in the 64th minute to a positive reception from the Manchester United fans.': array([[ 0.00746889,  0.08165129,  0.07595788, ...,  0.08947519,
#           0.04768771, -0.00153451]], dtype=float32),
#  'The match was the first time Beckham had played against Manchester United at Old Trafford and saw him create several scoring opportunities via crosses and corner kicks, but Manchester United dominated Milan and beat them 4–0, winning the tie 7–2.': array([[ 0.00746889,  0.02193393,  0.07198244, ...,  0.05138626,
#           0.03394919, -0.00084022]], dtype=float32),
#  "As the fan protests against Glazer by the people gathered around Manchester United Supporters' Trust gained steam in 2010, the green-and-gold scarf had come to be seen as an anti-Glazer symbol, and by extension many saw Beckham's decision to publicly put it on as gesture of support.": array([[ 0.00746889, -0.05875353,  0.13306957, ...,  0.05915658,
#           0.03473583,  0.0107982 ]], dtype=float32),
#  "In Milan's next game, against ChievoVerona, Beckham suffered a torn left Achilles tendon, causing him to miss the World Cup as well as the MLS season due to the injury, which took him out of action for the next five months.": array([[0.00746889, 0.01713657, 0.06442246, ..., 0.1275779 , 0.03750378,
#          0.03027181]], dtype=float32),
#  'After the operation, Orava affirmed that: "it went quite fine.': array([[ 0.00746889, -0.07554492,  0.18934833, ...,  0.03783387,
#          -0.01783358,  0.05758429]], dtype=float32),
#  'I would say that [it will be] maybe four months before he\'s running, but six months before he\'s jumping and kicking."': array([[ 0.00746889, -0.01576716, -0.01102921, ...,  0.07850282,
#          -0.01393405,  0.00103167]], dtype=float32),
#  'On 4 October, Beckham scored a trademark free kick in a 2–1 win over Chivas to mark his first goal in 2010.': array([[0.00746889, 0.0332899 , 0.16285904, ..., 0.05442853, 0.04963524,
#          0.03085734]], dtype=float32),
#  'During January and February 2011, ahead of the 2011 MLS season, Beckham trained with Tottenham Hotspur.': array([[ 0.00746889, -0.06240555,  0.10056219, ...,  0.14384647,
#           0.03798379,  0.03019213]], dtype=float32),
#  'As a result, he ended up only training with the club as he had done with Arsenal three years earlier.': array([[ 0.00746889,  0.01264775,  0.0361045 , ...,  0.0726131 ,
#          -0.01889986,  0.00908737]], dtype=float32),
#  'MLS Cup championEdit\n\nOn 15 May, Beckham scored his first goal of the season for the Galaxy from a 30-yard free kick, in a 4–1 victory over Sporting Kansas City.': array([[0.00746889, 0.04182676, 0.13539028, ..., 0.10750174, 0.05727552,
#          0.02952783]], dtype=float32),
#  'After having his best season with the Galaxy to date and finishing second in the league in assists, Beckham finished his fifth MLS season on a high.': array([[0.00746889, 0.03508974, 0.13883527, ..., 0.13889998, 0.07098197,
#          0.01930753]], dtype=float32),
#  "Had it been Beckham's final match for the Galaxy, it would have been the third time he has won a league championship in his final match for a club, repeating the feat he accomplished with Manchester United in 2003 and Real Madrid in 2007.": array([[0.00746889, 0.03144294, 0.06303275, ..., 0.08193313, 0.03972979,
#          0.01533624]], dtype=float32),
#  'Despite being 36, he stated that he did not intend to retire.': array([[ 0.00746889,  0.01318669, -0.02359075, ...,  0.08499491,
#           0.0189633 , -0.0138564 ]], dtype=float32),
#  'In May 2012, Beckham and his victorious team-mates were received by U.S. President Barack Obama at the White House.': array([[ 0.00746889,  0.03393679,  0.0682776 , ...,  0.02614182,
#           0.05444131, -0.01032147]], dtype=float32),
#  'The Galaxy defeated Vancouver, San Jose, Seattle and then 3–1 over Houston to retain the MLS Cup.': array([[ 0.00746889,  0.03761882,  0.0407437 , ...,  0.0752701 ,
#           0.07082693, -0.01385639]], dtype=float32),
#  'Beckham had earlier announced that the 2012 MLS Cup Final would be his final game with the Galaxy despite having another year remaining on his contract.': array([[0.00746889, 0.02865363, 0.03989029, ..., 0.07299288, 0.00811094,
#          0.02399501]], dtype=float32),
#  "Beckham signed a five-month deal with the club later that afternoon and confirmed that his entire salary during his time in Paris would be donated to a local children's charity.": array([[0.00746889, 0.02661785, 0.1594899 , ..., 0.08187378, 0.02896363,
#          0.02488396]], dtype=float32),
#  'This made him the 400th player in the history of the club.': array([[ 0.00746889,  0.03719069,  0.11903324, ...,  0.03387116,
#          -0.00939381,  0.02645608]], dtype=float32),
#  "On 16 May 2013, Beckham announced that he would retire from professional football at the end of that year's French football season.": array([[0.00746889, 0.00988945, 0.08708191, ..., 0.0945646 , 0.02714995,
#          0.01918188]], dtype=float32),
#  'These boots had the names of his wife, Victoria, and children stitched on to them.': array([[ 0.00746889,  0.09980074,  0.13726777, ...,  0.03696514,
#          -0.00443033, -0.00030162]], dtype=float32),
#  'In this game Beckham assisted a goal by Matuidi from a corner.': array([[ 0.00746889, -0.03995881,  0.12399622, ...,  0.05609446,
#           0.01996132, -0.00308935]], dtype=float32),
#  'PSG went on to win the game 3–1.': array([[ 0.00746889, -0.09882732,  0.05429557, ...,  0.03422471,
#          -0.0045687 , -0.00673837]], dtype=float32),
#  "Beckham had played in all of England's qualifying matches for the 1998 World Cup and was part of the England squad at the World Cup finals in France, but the team's manager Glenn Hoddle publicly accused him of not concentrating on the tournament, and he did not start in either of England's first two games.": array([[0.00746889, 0.02387255, 0.04249313, ..., 0.09109594, 0.0629914 ,
#          0.00122615]], dtype=float32),
#  "In the second round (last 16) of that competition, he received a red card in England's match against Argentina.": array([[ 0.00746889,  0.00304658,  0.08182225, ...,  0.07506352,
#          -0.0114797 ,  0.00939733]], dtype=float32),
#  'Sports Illustrated was critical of the Argentinians\' theatrics in that incident, stating that Simeone first delivered a "heavy-handed challenge" on Beckham and then "fell like a ton of bricks" when Beckham retaliated.': array([[0.00746889, 0.02574063, 0.11377901, ..., 0.0653109 , 0.06024765,
#          0.0050649 ]], dtype=float32),
#  'The match finished in a draw and England were eliminated in a penalty shootout.': array([[ 0.00746889, -0.00717035,  0.04592969, ...,  0.00441366,
#          -0.01529237, -0.01131735]], dtype=float32),
#  'Beckham also received death threats after the World Cup.': array([[ 0.00746889, -0.03777931,  0.06297155, ...,  0.00330765,
#           0.05124673, -0.00445123]], dtype=float32),
#  'Beckham responded by raising his middle finger and, while the gesture attracted some criticism, many of the newspapers that had previously encouraged his vilification asked their readers to stop abusing him.': array([[ 0.00746889,  0.04486075,  0.10235716, ...,  0.03714424,
#           0.05745924, -0.01112751]], dtype=float32),
#  'Beckham played a major role in helping England qualify for the 2002 FIFA World Cup, starring in an impressive 5–1 victory over Germany in Munich.': array([[ 0.00746889, -0.03777931,  0.12952296, ...,  0.08585436,
#           0.04191949,  0.01620166]], dtype=float32),
#  'England needed to win or draw the match to qualify outright for the World Cup, but were losing 2–1 with little time remaining.': array([[ 0.00746889, -0.02546099,  0.04595832, ...,  0.04267668,
#           0.04237315, -0.0092745 ]], dtype=float32),
#  'Beckham was voted the BBC Sports Personality of the Year for 2001, and finished runner-up, to Luís Figo of Portugal, for the FIFA World Player of the Year award.': array([[ 0.00746889, -0.01689652,  0.13308656, ...,  0.08132497,
#           0.02621677,  0.00957436]], dtype=float32),
#  'After the events of four years earlier, Beckham achieved a degree of revenge over Argentina by scoring the winning goal with a penalty, causing Argentina to fail to qualify for the knockout stage.': array([[ 0.00746889, -0.02600138,  0.06622855, ...,  0.03559049,
#           0.04534971,  0.03215702]], dtype=float32),
#  'England were knocked out in the quarter-finals by eventual winners Brazil after Ronaldinho scored the winner.': array([[ 0.00746889, -0.04964336,  0.1052109 , ...,  0.04645207,
#           0.03358319,  0.01935947]], dtype=float32),
#  "Beckham played in all of England's matches at Euro 2004.": array([[ 0.00746889, -0.0076784 ,  0.04252253, ...,  0.06262522,
#           0.05672975,  0.00878675]], dtype=float32),
#  'England lost the shootout thus going out of the competition.': array([[ 0.00746889, -0.03805416, -0.01733346, ...,  0.03648664,
#          -0.01012608, -0.01385639]], dtype=float32),
#  "In October 2005, Beckham's sending off against Austria made him the first England captain to be sent off and the first player to be sent off twice while playing for England.": array([[0.00746889, 0.01787494, 0.05637686, ..., 0.04951378, 0.04667611,
#          0.02618298]], dtype=float32),
#  "In England's opening game at the 2006 World Cup, against Paraguay on 10 June 2006, Beckham's free kick led to an own-goal by Carlos Gamarra as England won 1–0.": array([[ 0.00746889, -0.02449781,  0.11087874, ...,  0.06063418,
#           0.04515865,  0.01883751]], dtype=float32),
#  'Beckham gave another assist to Steven Gerrard.': array([[0.00746889, 0.08635786, 0.15125719, ..., 0.04217688, 0.02720759,
#          0.00392961]], dtype=float32),
#  'He was named Man of the Match by tournament sponsor Budweiser.': array([[0.00746889, 0.16078709, 0.10547297, ..., 0.04578211, 0.05583985,
#          0.01711463]], dtype=float32),
#  'He was sick before the game and vomited several times as a result of dehydration and illness that he got after having scored the winning goal for England.': array([[0.00746889, 0.01175361, 0.07829741, ..., 0.08613066, 0.00496403,
#          0.01778795]], dtype=float32),
#  'After his substitution, Beckham was visibly shaken and emotional for not being able to play, being in tears at one point.': array([[ 0.00746889,  0.05504584,  0.01739208, ...,  0.04460501,
#           0.06508268, -0.00406587]], dtype=float32),
#  '(Beckham had won 94 caps up to that point.)': array([[ 0.00746889, -0.03243299,  0.08419109, ...,  0.02475753,
#           0.05087638, -0.00080188]], dtype=float32),
#  'Having stepped down as captain after the World Cup, Beckham was dropped completely from the England national team selected by new coach Steve McClaren on 11 August 2006.': array([[0.00746889, 0.07091059, 0.08303899, ..., 0.07090983, 0.05006611,
#          0.03533473]], dtype=float32),
#  'McClaren said Beckham could be recalled in future.': array([[ 0.00746889, -0.03173881, -0.05422354, ...,  0.04701215,
#           0.05153053,  0.00245802]], dtype=float32),
#  'On 26 May 2007, McClaren announced that Beckham would be recalled to the England squad for the first time since stepping down as their captain.': array([[ 0.00746889, -0.04675058, -0.00369459, ...,  0.0467571 ,
#           0.02866584,  0.02515265]], dtype=float32),
#  "In the second half, he set up England's goal converted by captain John Terry.": array([[0.00746889, 0.11000814, 0.06560091, ..., 0.07377892, 0.01192647,
#          0.0040018 ]], dtype=float32),
# ...
#           0.09030136, -0.01385639]], dtype=float32),
#  "We've got three fridges – food in one, salad in another and drinks in the third.": array([[ 0.00746889, -0.04778164,  0.05242933, ...,  0.00312212,
#           0.04245204,  0.00105942]], dtype=float32),
#  'If there\'s three cans, he\'ll throw one away because it has to be an even number."': array([[ 0.00746889,  0.00990729, -0.00352262, ...,  0.09397295,
#           0.04356313, -0.00204363]], dtype=float32),
#  'A week later, the Malaysian-born Australian model Sarah Marbeck claimed that she had slept with Beckham on two occasions.': array([[ 0.00746889, -0.03649444,  0.02015048, ...,  0.05027416,
#           0.0764447 , -0.0011712 ]], dtype=float32),
#  'In September 2010, Beckham announced that he was making a court application against prostitute Irma Nici and several others over claims in the magazine In Touch that he had had sex with her.': array([[0.00746889, 0.01061372, 0.13137294, ..., 0.07696094, 0.07331211,
#          0.02606129]], dtype=float32),
#  'Outside footballEdit\n\nBeckham\'s fame extends beyond the pitch; in much of the world his name is "as instantly recognisable as that of multinational companies like Coca-Cola and IBM."': array([[0.00746889, 0.02212991, 0.11256436, ..., 0.05817544, 0.05270759,
#          0.03477701]], dtype=float32),
#  'Beckham became known as a fashion icon, and together with Victoria, the couple became lucrative spokespeople sought after by clothing designers, health and fitness specialists, fashion magazines, perfume and cosmetics manufacturers, hair stylists, exercise promoters, and spa and recreation companies.': array([[ 0.00746889, -0.03777931,  0.13421728, ...,  0.03681377,
#           0.04609427,  0.00140441]], dtype=float32),
#  'In 2002, Beckham was hailed as the ultimate "metrosexual" by the man who invented the term and has been described as such by numerous other articles since.': array([[0.00746889, 0.27356088, 0.13499226, ..., 0.04270792, 0.07700863,
#          0.00672414]], dtype=float32),
#  'In the world of fashion, David has already appeared on the covers of many magazines.': array([[ 0.00746889,  0.06718452,  0.06146666, ...,  0.04519163,
#           0.0360259 , -0.00297067]], dtype=float32),
#  'According to Ask Jeeves, Beckham ranked third, after Britney Spears and Osama bin Laden, among subjects most searched for by British users of that site in the first decade of the 2000s.': array([[ 0.00746889, -0.02413625,  0.11632991, ...,  0.06095452,
#           0.08543304, -0.00153744]], dtype=float32),
#  'On the next night, Victoria appeared on The Tonight Show with Jay Leno to talk about the their move to LA, and presented Leno with a number 23 Galaxy jersey with his own name on the back.': array([[0.00746889, 0.06480566, 0.11119291, ..., 0.0755804 , 0.07220964,
#          0.01784824]], dtype=float32),
#  'On 22 July, a private welcoming party was held for the couple at the Museum of Contemporary Art, Los Angeles.': array([[ 0.00746889, -0.05727342,  0.14403763, ..., -0.00019411,
#           0.11197247,  0.02633235]], dtype=float32),
#  "Beckham's many endorsement deals make him one of the most recognisable athletes throughout the world.": array([[0.00746889, 0.0172937 , 0.0679459 , ..., 0.04510236, 0.0358981 ,
#          0.00868336]], dtype=float32),
#  'He had a 10-year collaboration with Pepsi Co. that expired in 2009.': array([[0.00746889, 0.01175361, 0.13112478, ..., 0.07947675, 0.02618429,
#          0.00390806]], dtype=float32),
#  'He has also promoted Walt Disney Co. theme parks.': array([[ 0.00746889,  0.01175361,  0.11090641, ...,  0.05998513,
#           0.04381284, -0.00148404]], dtype=float32),
#  'Beckham has several eponymous video games, including Go!': array([[ 0.00746889, -0.03777931,  0.04633962, ...,  0.03891037,
#           0.02073265,  0.00286066]], dtype=float32),
#  'Beckham!': array([[ 0.00746889, -0.03777931, -0.02181155, ..., -0.01750857,
#           0.06013395,  0.00222369]], dtype=float32),
#  "Beckham featured in EA Sports' FIFA video game series; he was on the cover for the International edition of FIFA 98.": array([[ 0.00746889, -0.00107073,  0.08285239, ...,  0.0961275 ,
#           0.05175306,  0.01570012]], dtype=float32),
#  "In 2006, Lloyd's of London insured his legs for £100m, at the time he was playing for Real Madrid.": array([[0.00746889, 0.04491075, 0.06041612, ..., 0.05244122, 0.01022416,
#          0.01057146]], dtype=float32),
#  'Beckham visited Afghanistan in May 2010 for a morale-boosting visit to British troops fighting the Taliban insurgency.': array([[ 0.00746889, -0.03777931,  0.12101056, ...,  0.03418198,
#           0.01588963,  0.00786153]], dtype=float32),
#  'Chinese authorities appointed Beckham as global ambassador for Chinese football in March 2013.': array([[ 0.00746889,  0.0016357 ,  0.10615904, ...,  0.04370362,
#           0.05634903, -0.00145582]], dtype=float32),
#  'From 14 July 2013, Beckham started appearing in adverts for BSkyB advertising their Sky Sports coverage via the Sky Go app.': array([[0.00746889, 0.03841348, 0.13305837, ..., 0.02899859, 0.03861906,
#          0.0639981 ]], dtype=float32),
#  "He was named one of GQ's 50 best dressed British men in 2015.": array([[0.00746889, 0.28398472, 0.14195836, ..., 0.08329275, 0.06396531,
#          0.00753357]], dtype=float32),
#  'In 2012 he met with UK Prime Minister David Cameron at 10 Downing Street to call for more action to help children affected by malnutrition around the world.': array([[ 0.00746889,  0.09080459,  0.06315786, ...,  0.07734127,
#           0.05438847, -0.00869338]], dtype=float32),
#  'In June 2015 he visited Siem Reap in Cambodia, where he met with child victims of violence.': array([[ 0.00746889,  0.03011641,  0.02169442, ...,  0.08058827,
#          -0.00402425,  0.01931272]], dtype=float32),
#  'He is also a patron of the Elton John AIDS Foundation.': array([[ 0.00746889,  0.12371585,  0.14365624, ...,  0.0447751 ,
#           0.03267656, -0.01385639]], dtype=float32),
#  'After the conversation, he sent her a Real Madrid jersey with his signature on it.': array([[ 0.00746889,  0.02617241,  0.11006562, ...,  0.06893516,
#           0.03983301, -0.0014669 ]], dtype=float32),
#  'Beckham is a founding member of the Malaria No More UK Leadership Council and helped launch the charity in 2009 with Andy Murray at Wembley Stadium.': array([[0.00746889, 0.04343553, 0.13187909, ..., 0.07793521, 0.02197998,
#          0.01933787]], dtype=float32),
#  'The TV spot aired in the U.S. on Fox Networks, including Fox Soccer Channel, and can also be seen on YouTube.': array([[ 0.00746889, -0.06945133,  0.07372602, ..., -0.0266807 ,
#           0.01154147,  0.03278523]], dtype=float32),
#  'On 17 August 2007, he conducted a youth clinic in Harlem, along with other current and former MLS players.': array([[0.00746889, 0.02226467, 0.09972555, ..., 0.10794839, 0.04271073,
#          0.02513543]], dtype=float32),
#  "That team's Jozy Altidore and Juan Pablo Ángel were also with Beckham, teaching skills to disadvantaged youth to benefit FC Harlem Lions.": array([[0.00746889, 0.0179907 , 0.1156259 , ..., 0.04703783, 0.03392742,
#          0.01619029]], dtype=float32),
#  'He and his wife wanted to make cameo appearances, but scheduling proved difficult, so the director used lookalike Andy Harmer instead.': array([[0.00746889, 0.1069212 , 0.09601425, ..., 0.06181714, 0.00380966,
#          0.01021126]], dtype=float32),
#  ': The Dream Begins.': array([[ 0.00746889, -0.05999579,  0.01304261, ..., -0.0415594 ,
#          -0.02496598, -0.01385639]], dtype=float32),
#  'Beckham himself appears in the sequel Goal!': array([[ 0.00746889,  0.04839471,  0.03178948, ...,  0.02329533,
#           0.06055388, -0.00570608]], dtype=float32),
#  'This time the story centres on the Real Madrid team, and besides Beckham, other real life Real Madrid players also appear on and off the pitch, alongside the fictional characters.': array([[0.00746889, 0.04317646, 0.04908654, ..., 0.06184366, 0.04366042,
#          0.00819305]], dtype=float32),
#  '3: Taking on the World, which was released straight to DVD on 15 June 2009.': array([[0.00746889, 0.03117278, 0.05393657, ..., 0.01633903, 0.03687456,
#          0.02459046]], dtype=float32),
#  'Beckham appears as a projectionist in the Guy Ritchie-directed action film The Man from U.N.C.L.E., based on the 1964 MGM television series of the same name.': array([[0.00746889, 0.17411369, 0.05519073, ..., 0.01135355, 0.0298295 ,
#          0.02770541]], dtype=float32),
#  "With his free kick goal against Ecuador in the second round of the 2006 FIFA World Cup, Beckham gained membership into two of football's exclusive clubs: he became the only English player – and the 21st player regardless of nationality – to score in three world cups; Real Madrid teammate Raúl also achieved this feat a few days earlier.": array([[0.00746889, 0.04598057, 0.13748229, ..., 0.08888274, 0.04650228,
#          0.02171979]], dtype=float32),
#  'All three goals were against South American teams (Colombia, Argentina, and Ecuador) and from set pieces (the two aforementioned free kicks and a penalty against Argentina).': array([[0.00746889, 0.03328385, 0.10215356, ..., 0.0538057 , 0.01672644,
#          0.00866792]], dtype=float32),
#  'There are names of his sons Romeo, Cruz and Brooklyn, and the name of his wife Victoria.': array([[ 0.00746889,  0.23623611,  0.07250504, ...,  0.02732347,
#           0.0325991 , -0.00081524]], dtype=float32),
#  "Unfortunately, this was misspelt as the equivalent of 'Vihctoria'.": array([[ 0.00746889, -0.03884076,  0.02736913, ..., -0.02118441,
#           0.02037774, -0.00580153]], dtype=float32),
#  'In his autobiography "David Beckham: My Side", he revealed some of his thoughts on tattoos: "The idea came to me much later, a little while after Brooklyn was born.': array([[0.00746889, 0.08826574, 0.0217114 , ..., 0.08198725, 0.08986207,
#          0.00680428]], dtype=float32),
#  "I ended up going to this Dutch guy who'd done all of Jimmy's.": array([[ 0.00746889,  0.13316888,  0.04357084, ...,  0.04831507,
#          -0.01453097,  0.00214044]], dtype=float32),
#  'Mine are all about the people in my life, my wife and sons, who I want with me always.': array([[ 0.00746889,  0.19493388,  0.01932075, ...,  0.02310579,
#          -0.00641955,  0.00372843]], dtype=float32),
#  'You see an expression of how I feel about Victoria and the boys.': array([[ 0.00746889,  0.17186168,  0.05778953, ...,  0.02118938,
#           0.02233013, -0.00547083]], dtype=float32),
#  'AwardsEdit\n\n\nCareer statisticsEdit\n\n\nClubEdit\n\n\nInternationalEdit\n\n\nHonoursEdit\n\n\nClubEdit\nManchester United\nPremier League (6): 1995–96, 1996–97, 1998–99, 1999–2000, 2000–01, 2002–03\nFA Cup (2): 1995–96, 1998–99\nFA Community Shield (2): 1996, 1997\nUEFA Champions League (1): 1998–99\nIntercontinental Cup (1): 1999\nReal Madrid\nLa Liga (1): 2006–07\nSupercopa de España (1): 2003\nLos Angeles Galaxy\nMLS Cup (2): 2011, 2012\nMLS Supporters\' Shield (2): 2010, 2011\nMLS Western Conference\nWinners (Regular Season) (3): 2009, 2010, 2011\nWinners (Playoffs) (3): 2009, 2011, 2012\n\nParis Saint-Germain\nLigue 1 (1): 2012–13\n\n\nInternationalEdit\nEngland\nTournoi de France: 1997\nFA Summer Tournament: 2004\n\n\nIndividualEdit\n\nBallon d\'Or – Runner-up: 1999\nFIFA World Player of the Year – Silver Award: 1999, 2001\nPremier League Player of the Month (1): August 1996\nPFA Young Player of the Year (1): 1996–97\nFWA Tribute Award: 2008\nSir Matt Busby Player of the Year (1): 1996–97\nEngland Player of the Year: 2003\nESM Team of the Year: 1998–99\nUEFA Club Footballer of the Year (1): 1998–99\nUEFA Club Midfielder of the Year (1): 1998–99\nUEFA Team of the Year: 2001, 2003\nPremier League 10 Seasons Awards (1992–93 to 2001–02):\nDomestic & Overall Team of the Decade\nGoal of the Decade (vs. Wimbledon, 17 August 1996)\n\nBBC Sports Personality of the Year (1): 2001\nBBC Sports Personality of the Year Lifetime Achievement Award (1): 2010\nReal Madrid Player of the Year (1): 2005–06\nPremier League PFA Team of the Year (4): 1996–97, 1997–98, 1998–99, 1999–2000\nFIFA 100\nESPY Awards:\nBest Male Soccer Player: 2004\nBest MLS Player (2): 2008, 2012\n\nEnglish Football Hall of Fame: 2008\nMLS Comeback Player of the Year Award (1): 2011\n\n\nOrders and special awardsEdit\nOfficer of the Order of the British Empire by Queen Elizabeth II: 2003\nUnited Nations Children\'s Fund (UNICEF) Goodwill Ambassador (2005–present)\n"Britain\'s Greatest Ambassador" – 100 Greatest Britons awards\nThe Celebrity 100, number 15 – Forbes, 2007\nNumber 1 on the list of the 40 most influential men under the age of 40 in the UK – Arena, 2007\nTime 100: 2008\nGold Blue Peter Badge winner, 2001\nDo Something Athlete Award, 2011\n\n\nRecordsEdit\nFirst Englishman to win league titles in four different countries (England, Spain, United States, France).': array([[0.00746889, 0.26393393, 0.16387665, ..., 0.11672405, 0.13943456,
#          0.04369668]], dtype=float32),
#  'First British footballer to play 100 UEFA Champions League games.': array([[ 0.00746889,  0.03656334,  0.08536996, ...,  0.03498592,
#           0.08601342, -0.00681662]], dtype=float32),
#  'See alsoEdit\nFranchise player\n\n\nReferencesEdit\n\n\nBooksEdit\nBeckham, David (2002).': array([[0.00746889, 0.07965897, 0.04067587, ..., 0.03057612, 0.05849991,
#          0.00167748]], dtype=float32),
#  'HarperCollinsWillow.': array([[ 0.00746889, -0.10961374, -0.06461935, ..., -0.06896786,
#          -0.04434213, -0.01385639]], dtype=float32),
#  'Beckham, David; Freeman, Dean (2001).': array([[ 0.00746889,  0.08059716,  0.03201546, ...,  0.02230513,
#           0.0518468 , -0.00482993]], dtype=float32),
#  'Hodder & Stoughton.': array([[ 0.00746889, -0.11218071,  0.04058147, ..., -0.05426971,
#          -0.0137804 , -0.0138564 ]], dtype=float32),
#  'Beckham, David; Watt, Tom (2003).': array([[ 0.00746889,  0.09815174,  0.03201546, ...,  0.02448192,
#           0.05572769, -0.00533847]], dtype=float32),
#  'HarperCollins.': array([[ 0.00746889, -0.09885065,  0.01891316, ..., -0.00259646,
#           0.06005594, -0.0138564 ]], dtype=float32),
#  'Crick, Michael (2003).': array([[0.00746889, 0.08536556, 0.11310882, ..., 0.00800925, 0.00079977,
#          0.00224397]], dtype=float32),
#  'Pocket Books.': array([[ 0.00746889, -0.06615148,  0.09008953, ..., -0.04135679,
#          -0.00430669, -0.0138564 ]], dtype=float32),
#  'Ferguson, Alex; McIlvanney, Hugh (1999).': array([[ 0.00746889,  0.09774235,  0.05544915, ...,  0.03149558,
#           0.03831184, -0.00317638]], dtype=float32),
#  'ISBN 978-0-340-72855-0.': array([[ 0.00746889, -0.10194571,  0.08497151, ..., -0.03242138,
#          -0.02491331, -0.0138564 ]], dtype=float32),
#  "The Beckham Experiment: How the World's Most Famous Athlete Tried to Conquer America.": array([[ 0.00746889, -0.02089073,  0.09835394, ...,  0.04474888,
#           0.0697275 ,  0.01015164]], dtype=float32),
#  'ISBN 978-0-307-40859-4.': array([[ 0.00746889, -0.10194571,  0.08497151, ..., -0.03242138,
#          -0.02491331, -0.0138564 ]], dtype=float32),
#  '"Beckham\'s Last Stand: In the fifth and final year of his MLS contract, he\'s back at the top of his game at last.': array([[0.00746889, 0.02840639, 0.08425272, ..., 0.11803327, 0.02664038,
#          0.02596033]], dtype=float32),
#  'Sports Illustrated.': array([[ 0.00746889, -0.11990518,  0.11377901, ..., -0.06896786,
#          -0.01441249, -0.0138564 ]], dtype=float32),
#  "'In [Major League Soccer] his ability to hold the ball in that position and pass makes him unique,' says [coach Bruce] Arena.": array([[ 0.00746889,  0.05063922,  0.10575289, ...,  0.05039236,
#           0.01380261, -0.00881208]], dtype=float32),
#  "In every game, he touches the ball the most of any player.'": array([[ 0.00746889,  0.0131172 ,  0.01395027, ...,  0.0579109 ,
#          -0.01528962, -0.01104911]], dtype=float32)}
